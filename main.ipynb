# %%
# This is the main Notebook instance that we will use to run the program
# %pip uninstall -y fsspec boto3 s3fs
# %pip install boto3 real-simple-seismic fsspec
# Out:
# Found existing installation: fsspec 2021.4.0
# Uninstalling fsspec-2021.4.0:
#   Successfully uninstalled fsspec-2021.4.0
# Found existing installation: boto3 1.17.53
# Uninstalling boto3-1.17.53:
#   Successfully uninstalled boto3-1.17.53
# Found existing installation: s3fs 0.6.0
# Uninstalling s3fs-0.6.0:
#   Successfully uninstalled s3fs-0.6.0
# Note: you may need to restart the kernel to use updated packages.
# ...
#   Using cached boto3-1.17.53-py2.py3-none-any.whl (131 kB)
# ...
#   Using cached fsspec-2021.4.0-py3-none-any.whl (108 kB)
# ...
#   Using cached s3fs-0.6.0-py3-none-any.whl (23 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from mypackage.utils import loader

# %%
well_seismic = loader()
# Out:
# Connection complete.

# %%
for i in well_seismic:
    for j in well_seismic[i]:
        print(i,j,well_seismic[i][j])
# Out:
# well_01 near [[[-0.92938017 -0.92938017 -0.92938017 ... -0.92938017 -0.92938017
#    -0.92938017]
#   [-0.92938017 -0.92938017 -0.92938017 ... -0.92938017 -0.92938017
#    -0.92938017]
#   [-0.92938017 -0.92938017 -0.92938017 ... -0.92938017 -0.92938017
#    -0.92938017]
#   ...
#   [-0.92938017 -0.92938017 -0.92938017 ... -0.92938017 -0.92938017
#    -0.92938017]
#   [-0.92938017 -0.92938017 -0.92938017 ... -0.92938017 -0.92938017
#    -0.92938017]
#   [-0.92938017 -0.92938017 -0.92938017 ... -0.92938017 -0.92938017
#    -0.92938017]]
#
#  [[-2.32392346 -2.32392346 -2.32392346 ... -2.32392346 -2.32392346
#    -2.32392346]
#   [-2.32392346 -2.32392346 -2.32392346 ... -2.32392346 -2.32392346
#    -2.32392346]
#   [-2.32392346 -2.32392346 -2.32392346 ... -2.32392346 -2.32392346
#    -2.32392346]
#   ...
#   [-2.32392346 -2.32392346 -2.32392346 ... -2.32392346 -2.32392346
#    -2.32392346]
#   [-2.32392346 -2.32392346 -2.32392346 ... -2.32392346 -2.32392346
#    -2.32392346]
# ...
